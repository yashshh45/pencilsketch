# %% [markdown]
# # Image Pencil Sketch App

# %% [markdown]
# Installing OpenCV Library

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opencv-python) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# Taking image input

# %%
img=cv2.imread('1233459.jpg')

# %% [markdown]
# Converting BGR to RGB

# %%
image=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# Converting img to grayscale

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray_img,cmap='gray')
plt.show()

# %% [markdown]
# Inverting grayscale img

# %%
inverted=~gray_img

# %%
plt.imshow(inverted,cmap='gray')
plt.show()

# %% [markdown]
# Applying Gaussian Blur to remove noise

# %%
blurred_img=cv2.GaussianBlur(inverted,(21,21),0)

# %%
plt.imshow(blurred_img,cmap='gray')
plt.show()

# %% [markdown]
# Converting img to Pencil Sketch

# %%
dodged=cv2.divide(gray_img,255-blurred_img,scale=256)

# %%
plt.imshow(dodged,cmap='gray')
plt.show()
